# %% [markdown]
# # Análisis exploratorio - Universidad de la Costa
# Integrantes: Hernando Luiz Calvo Ochoa, Carlos Antonio Ardila Ruiz

# %%
import pandas as pd

path = '/mnt/data/university_student_data.csv'
df = pd.read_csv(path)
df.head()
